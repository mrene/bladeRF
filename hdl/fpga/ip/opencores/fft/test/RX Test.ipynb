# %%
# %matplotlib inline
import itertools
from scipy import signal
from scipy.fftpack import fft 
import numpy
import struct
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
from util import *

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
def getFFTSamples(src, fftlen):
    data = list(itertools.islice(src, 0, fftlen))
    absdata = np.abs(data)
    yield absdata


def plotFFTSamples(data):
    #absdata = np.abs(data)
    mag = 10*np.log10(data)
    mag = [max(x, 25) for x in mag]
    plt.plot(freq, mag)

# %%
src = binaryfile('./data-rx.bin')
fftlen = 2**10

# Average 100 fft results
for i in range(0,100):
    data = [ ]
    data += getFFTSamples(src, fftlen)
data = np.average(data,axis=0)
data
# Out:
# array([ 3806.99172576,  3434.60041344,  1025.        , ...,  1025.        ,
#         1379.53071731,  1846.04225304])

# %%
plotFFTSamples(data)

# %%
a = [ [ 1, 2, 3], [ 4, 5, 6], [ 7, 8, 9 ] ]

# %%
np.average(a, axis=0)
# Out:
# array([ 4.,  5.,  6.])

# %%
np.average([1, 4, 7])
# Out:
# 4.0

# %%
(1+2+3)/3
# Out:
# 2
